# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token. => UNK means Unknown words

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'originated', 'a', 'originated', 'of', 'as', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# WARNING:tensorflow:From /Users/youngmihuang/pyenv36/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.140763
# Nearest to five: ic, advancements, antilles, ismail, voss, sampa, nou, wifi,
# Nearest to and: stepfather, berth, shatila, expresses, vec, rd, introspective, gon,
# Nearest to there: mimi, choi, damage, antithetical, rgermeister, kombat, woodward, monolithic,
# Nearest to be: cistercian, wretched, hanoi, distress, noumenon, hickok, mccarthy, fragmented,
# Nearest to an: enterprise, shula, spoilage, debate, ceres, affirms, bench, cathode,
# Nearest to war: sceptical, dice, calculations, lamarck, equiv, citadel, counterexample, rioting,
# Nearest to in: silks, psychedelic, oliva, highlanders, industrial, intercal, livonian, told,
# Nearest to use: kanons, strategies, jefferson, mitre, clockwork, mambo, becomes, disposal,
# Nearest to all: grumpy, singularly, mouton, gygax, umlaut, florentine, diff, director,
# Nearest to is: transcending, highlighted, muted, valerie, silenced, bureaucrats, reliably, oddity,
# Nearest to s: installing, services, photosynthesis, levelling, oily, gonzo, rancher, climbed,
# Nearest to or: pisa, davros, uncharacteristically, grass, pileser, museum, eschewing, harman,
# Nearest to was: participates, gniezno, homilies, revolts, pokemon, exemplified, marshall, appreciated,
# Nearest to its: tunku, roles, milligan, linz, succeeded, florence, humboldt, hosokawa,
# Nearest to world: posterity, dutch, kashmiri, yokohama, lemur, establish, raping, cropping,
# Nearest to between: pours, unchanging, automata, specialised, concern, bahamas, kopp, antares,
# Average loss at step 2000: 4.370453
# Average loss at step 4000: 3.868096
# Average loss at step 6000: 3.792500
# Average loss at step 8000: 3.695558
# Average loss at step 10000: 3.616250
# Nearest to five: six, eight, four, three, seven, nine, two, zero,
# Nearest to and: or, in, american, airlift, of, makran, on, who,
# Nearest to there: it, he, stradella, often, also, they, choi, not,
# Nearest to be: have, is, was, nostrils, are, were, continues, existing,
# Nearest to an: the, cathode, gottlieb, its, aliphatic, sobib, ceres, usefully,
# Nearest to war: impacting, sceptical, second, discourages, counterexample, lewisham, calculations, pastiche,
# Nearest to in: on, of, at, and, dn, from, with, sadat,
# Nearest to use: cyclopedia, clockwork, disposal, ey, purify, mitsuda, criticised, capra,
# Nearest to all: mouton, many, gygax, director, grumpy, heralded, carolinas, singularly,
# Nearest to is: was, are, has, complied, be, brick, became, pcr,
# Nearest to s: his, and, hungarians, began, playboys, was, provisioning, her,
# Nearest to or: and, but, rattus, transient, com, philosophicus, receptor, neared,
# Nearest to was: is, has, by, were, had, childress, are, became,
# Nearest to its: the, his, their, fielder, a, regnant, an, delphi,
# Nearest to world: dutch, posterity, larousse, peptides, kashmiri, optical, cropping, pegbox,
# Nearest to between: with, rivalries, centralization, sieges, criticises, australia, dismissive, cereal,
# Average loss at step 12000: 3.610048
# Average loss at step 14000: 3.572742
# Average loss at step 16000: 3.412920
# Average loss at step 18000: 3.457304
# Average loss at step 20000: 3.544112
# Nearest to five: six, seven, four, eight, three, two, zero, nine,
# Nearest to and: or, which, but, eclectic, in, bookstores, chou, from,
# Nearest to there: it, they, he, often, now, also, which, noticing,
# Nearest to be: have, been, is, were, by, was, become, antigen,
# Nearest to an: the, gottlieb, its, aliphatic, sobib, apuleius, cathode, sampling,
# Nearest to war: second, impacting, switzer, sceptical, lewisham, treason, nabla, phenyl,
# Nearest to in: at, on, with, for, and, sifra, bode, dn,
# Nearest to use: purify, plantinga, cyclopedia, criticised, mitsuda, bodied, capra, cyclopes,
# Nearest to all: many, some, these, nl, hebrew, blankets, europeans, alastair,
# Nearest to is: was, has, are, be, at, fd, but, were,
# Nearest to s: industrialized, dassault, cotangent, handguns, anymore, report, his, fungus,
# Nearest to or: and, than, with, symbolized, dendrites, cisneros, rattus, futurism,
# Nearest to was: is, has, had, were, became, childress, jati, been,
# Nearest to its: their, his, the, fielder, dismissal, an, narrates, her,
# Nearest to world: peptides, optical, posterity, country, dutch, larousse, correspondent, millicent,
# Nearest to between: with, centralization, against, cereal, drivetrain, lavishly, criticises, federation,
# Average loss at step 22000: 3.503602
# Average loss at step 24000: 3.487791
# Average loss at step 26000: 3.484461
# Average loss at step 28000: 3.480967
# Average loss at step 30000: 3.506544
# Nearest to five: four, eight, six, seven, three, zero, nine, two,
# Nearest to and: or, in, but, polka, who, bursts, yelling, anarchist,
# Nearest to there: they, it, he, often, now, also, this, still,
# Nearest to be: have, been, was, sterility, is, were, become, refer,
# Nearest to an: gottlieb, apuleius, aliphatic, enterprise, jakob, methodist, sobib, wheeling,
# Nearest to war: phenyl, treason, second, impacting, lewisham, nabla, casting, switzer,
# Nearest to in: during, on, at, and, of, sadat, until, from,
# Nearest to use: plantinga, cyclopedia, cause, batsman, mitsuda, mickey, izmir, mass,
# Nearest to all: some, these, many, any, resold, several, declaring, jars,
# Nearest to is: was, has, are, became, were, fd, be, does,
# Nearest to s: his, her, wiccan, began, sinope, playboys, punctuation, cotangent,
# Nearest to or: and, symbolized, than, diem, but, yao, though, self,
# Nearest to was: is, had, has, were, been, became, childress, by,
# Nearest to its: their, his, the, fielder, her, dismissal, delphi, penguin,
# Nearest to world: peptides, dutch, country, factbook, optical, hurrians, flockhart, metabolism,
# Nearest to between: with, against, lavishly, centralization, watts, drivetrain, from, iggy,
# Average loss at step 32000: 3.498718
# Average loss at step 34000: 3.495994
# Average loss at step 36000: 3.458930
# Average loss at step 38000: 3.304999
# Average loss at step 40000: 3.431035
# Nearest to five: six, seven, four, three, zero, eight, nine, two,
# Nearest to and: or, but, in, UNK, bram, are, lb, including,
# Nearest to there: it, they, he, now, often, she, also, still,
# Nearest to be: been, have, refer, is, being, become, was, are,
# Nearest to an: cathode, incarnations, bench, wheeling, enterprise, gottlieb, permissive, the,
# Nearest to war: during, treason, lewisham, phenyl, impacting, daytime, terabytes, rest,
# Nearest to in: of, from, at, until, during, on, and, sadat,
# Nearest to use: plantinga, cyclopedia, cause, carina, need, mitsuda, form, barns,
# Nearest to all: both, these, several, heavily, any, resold, many, declaring,
# Nearest to is: was, has, are, sihanouk, fd, be, if, childress,
# Nearest to s: his, jes, whose, lifelong, fiefs, perigee, formants, wilhelmina,
# Nearest to or: and, than, frontiersman, cisneros, gamal, any, a, symbolized,
# Nearest to was: is, were, had, became, has, been, childress, being,
# Nearest to its: their, his, the, her, fielder, mjd, delphi, heterotic,
# Nearest to world: country, peptides, cropping, correspondent, factbook, posterity, akayev, nzwani,
# Nearest to between: with, lavishly, against, centralization, into, federation, from, over,
# Average loss at step 42000: 3.431818
# Average loss at step 44000: 3.457416
# Average loss at step 46000: 3.453352
# Average loss at step 48000: 3.349647
# Average loss at step 50000: 3.382466
# Nearest to five: four, six, seven, eight, three, zero, nine, two,
# Nearest to and: or, but, including, of, while, recitative, however, eurasia,
# Nearest to there: it, they, now, he, often, she, we, who,
# Nearest to be: been, become, have, was, being, refer, were, is,
# Nearest to an: enterprise, aliphatic, incarnations, joual, cathode, branding, ceases, monza,
# Nearest to war: lewisham, treason, during, phenyl, impacting, daytime, headstock, nabla,
# Nearest to in: during, from, on, at, within, of, proclaims, penal,
# Nearest to use: plantinga, need, izmir, form, cyclopedia, carina, phenotype, cause,
# Nearest to all: both, these, some, many, heavily, resold, any, cellists,
# Nearest to is: was, has, are, superheroes, be, fd, childress, became,
# Nearest to s: his, whose, wiccan, cotangent, lifelong, brainstem, anymore, kampong,
# Nearest to or: and, than, albinus, while, but, though, goncourt, dolly,
# Nearest to was: is, has, were, had, became, been, childress, be,
# Nearest to its: their, his, the, her, fielder, burnt, revolutionize, delphi,
# Nearest to world: dutch, footy, largest, nzwani, cropping, converges, country, factbook,
# Nearest to between: with, against, lavishly, into, among, centralization, dar, in,
# Average loss at step 52000: 3.437587
# Average loss at step 54000: 3.428023
# Average loss at step 56000: 3.438596
# Average loss at step 58000: 3.395719
# Average loss at step 60000: 3.392239
# Nearest to five: four, six, three, seven, zero, eight, nine, two,
# Nearest to and: or, but, than, including, sharing, in, like, although,
# Nearest to there: they, it, now, he, we, often, still, she,
# Nearest to be: been, become, was, have, refer, is, antigen, are,
# Nearest to an: enterprise, cathode, methodist, joual, colombo, citadels, gottlieb, sentinels,
# Nearest to war: lewisham, terabytes, during, phenyl, wars, treason, summarize, headstock,
# Nearest to in: during, within, since, baumgarten, at, from, on, until,
# Nearest to use: carina, cause, need, cyclopedia, plantinga, izmir, substances, purify,
# Nearest to all: these, both, those, some, many, various, any, several,
# Nearest to is: was, are, has, laurentiis, be, fd, soso, remains,
# Nearest to s: contagion, dassault, lifelong, jng, poetess, uninteresting, wilhelmina, wiccan,
# Nearest to or: and, than, envoy, albinus, slightly, etsi, sharing, frying,
# Nearest to was: is, had, became, were, childress, has, becomes, be,
# Nearest to its: their, his, the, her, repeatable, deconstructive, burnt, furigana,
# Nearest to world: largest, country, converges, dutch, footy, kaspar, hurrians, metabolism,
# Nearest to between: with, among, into, lavishly, against, from, in, lain,
# Average loss at step 62000: 3.240801
# Average loss at step 64000: 3.256026
# Average loss at step 66000: 3.404389
# Average loss at step 68000: 3.393646
# Average loss at step 70000: 3.358525
# Nearest to five: four, six, seven, three, eight, zero, nine, two,
# Nearest to and: or, while, which, but, yelling, like, however, albinus,
# Nearest to there: they, it, we, now, he, still, often, she,
# Nearest to be: been, is, become, being, were, have, was, easily,
# Nearest to an: enterprise, cathode, gottlieb, permissive, joual, incarnations, affirms, citadels,
# Nearest to war: wars, during, summarize, lewisham, daytime, axon, impacting, rest,
# Nearest to in: within, during, on, until, for, through, among, throughout,
# Nearest to use: need, cyclopedia, cause, chance, carina, define, form, plantinga,
# Nearest to all: some, both, many, various, these, those, any, every,
# Nearest to is: was, has, are, be, does, fd, became, actinide,
# Nearest to s: populous, rogues, riddle, lifelong, gec, proletarians, averroes, cotangent,
# Nearest to or: and, than, any, the, rattus, cisneros, while, dolly,
# Nearest to was: is, has, were, had, became, childress, been, be,
# Nearest to its: their, his, the, her, helvetii, several, them, prepaid,
# Nearest to world: largest, punchline, cropping, dutch, sale, hurrians, scope, ratified,
# Nearest to between: with, among, into, from, lavishly, dar, against, in,
# Average loss at step 72000: 3.376351
# Average loss at step 74000: 3.346760
# Average loss at step 76000: 3.314655
# Average loss at step 78000: 3.351013
# Average loss at step 80000: 3.374208
# Nearest to five: six, four, seven, three, eight, nine, zero, two,
# Nearest to and: or, while, but, yelling, although, however, including, than,
# Nearest to there: it, they, he, now, she, we, still, often,
# Nearest to be: been, being, become, have, were, antigen, is, was,
# Nearest to an: enterprise, gottlieb, cathode, aliphatic, coconuts, wheeling, incarnations, stateless,
# Nearest to war: wars, axon, calculations, impacting, daytime, headstock, summarize, lewisham,
# Nearest to in: within, during, on, at, until, with, around, sifra,
# Nearest to use: need, cause, cyclopedia, plantinga, draw, substances, because, sense,
# Nearest to all: both, various, any, every, several, many, some, these,
# Nearest to is: was, has, are, includes, childress, became, turnip, although,
# Nearest to s: andersonville, lac, wiccan, cotangent, rufus, kune, komondor, lifelong,
# Nearest to or: and, while, than, chakras, dolly, andrey, locative, rattus,
# Nearest to was: is, had, were, became, has, childress, been, aldo,
# Nearest to its: their, his, her, the, deconstructive, your, our, helvetii,
# Nearest to world: largest, footy, hurrians, kaspar, factbook, scope, sale, punchline,
# Nearest to between: with, among, into, within, over, in, from, lavishly,
# Average loss at step 82000: 3.405566
# Average loss at step 84000: 3.408721
# Average loss at step 86000: 3.389524
# Average loss at step 88000: 3.353842
# Average loss at step 90000: 3.367116
# Nearest to five: seven, four, six, three, eight, nine, zero, two,
# Nearest to and: or, but, while, corruptions, symbolized, yelling, although, however,
# Nearest to there: they, it, we, he, now, she, still, interventions,
# Nearest to be: been, have, become, was, being, is, refer, antigen,
# Nearest to an: enterprise, incarnations, cathode, continuously, nast, inaugurated, branding, sentinels,
# Nearest to war: wars, axon, during, headstock, rest, heydrich, phenyl, daytime,
# Nearest to in: during, within, on, until, with, around, jeremy, of,
# Nearest to use: need, cause, purify, sadism, barns, computable, kennel, draw,
# Nearest to all: both, several, some, every, various, those, any, many,
# Nearest to is: was, has, are, becomes, remains, petrograd, although, became,
# Nearest to s: lifelong, wiccan, whose, his, contagion, wrote, sinope, populous,
# Nearest to or: and, goose, but, rewrites, than, thessalian, giuseppe, while,
# Nearest to was: is, had, became, were, has, childress, been, be,
# Nearest to its: their, his, her, the, your, prepaid, deconstructive, our,
# Nearest to world: largest, factbook, footy, hurrians, ornithologists, hog, ajanta, disparities,
# Nearest to between: with, among, within, into, from, against, through, over,
# Average loss at step 92000: 3.397416
# Average loss at step 94000: 3.257898
# Average loss at step 96000: 3.359361
# Average loss at step 98000: 3.247280
# Average loss at step 100000: 3.359320
# Nearest to five: seven, four, six, eight, zero, three, two, nine,
# Nearest to and: or, but, although, however, while, when, journeyman, feuerbach,
# Nearest to there: they, it, we, he, now, often, still, she,
# Nearest to be: been, become, have, being, are, is, refer, antigen,
# Nearest to an: enterprise, wheeling, another, citadels, gottlieb, joual, cathode, basica,
# Nearest to war: wars, axon, flutist, headstock, phenyl, unsurprising, rest, magnetization,
# Nearest to in: during, within, until, on, throughout, from, at, of,
# Nearest to use: need, cause, sense, sadism, parameters, tishri, demand, production,
# Nearest to all: both, several, various, many, these, every, some, any,
# Nearest to is: was, has, are, fd, childress, became, be, remains,
# Nearest to s: whose, his, wiccan, lifelong, my, sarcasm, rogues, escalation,
# Nearest to or: and, than, alyattes, rattus, albinus, slightly, thessalian, lar,
# Nearest to was: is, became, has, had, were, becomes, childress, although,
# Nearest to its: their, his, the, her, fielder, lyricist, your, repeatable,
# Nearest to world: largest, factbook, footy, ornithologists, sqq, pharos, punchline, hurrians,
# Nearest to between: with, among, into, against, within, from, through, over,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
